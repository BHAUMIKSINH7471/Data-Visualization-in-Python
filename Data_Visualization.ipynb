# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
# Graph line for Plot the points.

# %%
x = [1, 2, 3]
y = [1, 4, 9]
z = [10, 5, 0]
plt.plot(x, y)
plt.plot(x, z)
plt.title('Test Plot')
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is y", "this is z"])
plt.show()

# %%
# Importing the real time data set in the form of csv files.

# %%
# To retrieve it in the tabular form.

# %%
data = pd.read_csv("annual.csv")

# %%
data
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2017                     Level 1                99999
# 1      2017                     Level 1                99999
# 2      2017                     Level 1                99999
# 3      2017                     Level 1                99999
# 4      2017                     Level 1                99999
# 5      2017                     Level 1                99999
# 6      2017                     Level 1                99999
# 7      2017                     Level 1                99999
# 8      2017                     Level 1                99999
# 9      2017                     Level 1                99999
# 10     2017                     Level 1                99999
# 11     2017                     Level 1                99999
# 12     2017                     Level 1                99999
# 13     2017                     Level 1                99999
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame
